# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from time import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# Load the datasets with ImageFolder
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
valid_data = datasets.ImageFolder(data_dir + '/valid', transform=valid_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

# Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=64)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# Load pretrained model
model = models.vgg19_bn(pretrained=True)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Redefine the classifier
def redefin_model(model):
    # Freeze parameters
    for param in model.parameters():
        param.requires_grad = False

    # Define feed-forward network
    from collections import OrderedDict
    classifier = nn.Sequential(OrderedDict([
                              ('fc1', nn.Linear(25088, 1024)),
                              ('relu', nn.ReLU()),
                              ('dropout1', nn.Dropout(0.2)),
                              ('fc2', nn.Linear(1024, 102)),
                              ('output', nn.LogSoftmax(dim=1))
                              ]))

    model.classifier = classifier
    return model

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
my_model = redefin_model(model)
optimizer = optim.Adam(my_model.classifier.parameters(), lr=0.00003)

my_model.to(device);

# %%
# Train the feed-forward network
def train_model(model, optimizer, trainloader, validloader, epochs=1, print_every=5):
    steps = 0
    running_loss = 0
    criterion = nn.NLLLoss()
    start_time = time()


    for epoch in range(epochs):
        for inputs, labels in trainloader:
            steps += 1
            # Move input and label tensors to the default device
            inputs, labels = inputs.to(device), labels.to(device)

            logps = model.forward(inputs)
            loss = criterion(logps, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:
                valid_loss = 0
                accuracy = 0
                model.eval()
                with torch.no_grad():
                    for inputs, labels in validloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        logps = model.forward(inputs)
                        batch_loss = criterion(logps, labels)

                        valid_loss += batch_loss.item()

                        # Calculate accuracy
                        ps = torch.exp(logps)
                        top_p, top_class = ps.topk(1, dim=1)
                        equals = top_class == labels.view(*top_class.shape)
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                
                end_time = time()
                total_time = end_time - start_time
                print(f"Epoch {epoch+1}/{epochs} Step {steps} "
                      f"Runtime: {total_time:.3f}  "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Validation loss: {valid_loss/len(validloader):.3f}.. "
                      f"Validation accuracy: {accuracy/len(validloader):.3f}")
                
                running_loss = 0
                model.train()

# %%
# keep session active to train the model
from workspace_utils import active_session

with active_session():
    train_model(model=my_model, optimizer=optimizer, trainloader=trainloader, validloader=validloader, epochs=20, print_every=10)
# Out:
# Epoch 1/20 Step 10 Runtime: 33.409  Train loss: 4.604.. Validation loss: 4.542.. Validation accuracy: 0.090
# Epoch 1/20 Step 20 Runtime: 66.742  Train loss: 4.520.. Validation loss: 4.428.. Validation accuracy: 0.123
# Epoch 1/20 Step 30 Runtime: 100.252  Train loss: 4.418.. Validation loss: 4.305.. Validation accuracy: 0.117
# Epoch 1/20 Step 40 Runtime: 133.640  Train loss: 4.332.. Validation loss: 4.195.. Validation accuracy: 0.083
# Epoch 1/20 Step 50 Runtime: 167.016  Train loss: 4.231.. Validation loss: 4.078.. Validation accuracy: 0.095
# Epoch 1/20 Step 60 Runtime: 200.385  Train loss: 4.083.. Validation loss: 3.944.. Validation accuracy: 0.148
# Epoch 1/20 Step 70 Runtime: 233.685  Train loss: 4.044.. Validation loss: 3.797.. Validation accuracy: 0.207
# Epoch 1/20 Step 80 Runtime: 267.275  Train loss: 3.882.. Validation loss: 3.647.. Validation accuracy: 0.273
# Epoch 1/20 Step 90 Runtime: 300.515  Train loss: 3.803.. Validation loss: 3.520.. Validation accuracy: 0.307
# Epoch 1/20 Step 100 Runtime: 333.767  Train loss: 3.739.. Validation loss: 3.384.. Validation accuracy: 0.329
# Epoch 2/20 Step 110 Runtime: 366.339  Train loss: 3.656.. Validation loss: 3.244.. Validation accuracy: 0.372
# Epoch 2/20 Step 120 Runtime: 399.597  Train loss: 3.403.. Validation loss: 3.122.. Validation accuracy: 0.380
# Epoch 2/20 Step 130 Runtime: 432.924  Train loss: 3.405.. Validation loss: 2.992.. Validation accuracy: 0.419
# Epoch 2/20 Step 140 Runtime: 466.211  Train loss: 3.309.. Validation loss: 2.893.. Validation accuracy: 0.441
# Epoch 2/20 Step 150 Runtime: 499.850  Train loss: 3.158.. Validation loss: 2.781.. Validation accuracy: 0.473
# Epoch 2/20 Step 160 Runtime: 533.047  Train loss: 3.149.. Validation loss: 2.669.. Validation accuracy: 0.513
# Epoch 2/20 Step 170 Runtime: 566.614  Train loss: 3.023.. Validation loss: 2.585.. Validation accuracy: 0.527
# Epoch 2/20 Step 180 Runtime: 600.012  Train loss: 2.988.. Validation loss: 2.476.. Validation accuracy: 0.546
# Epoch 2/20 Step 190 Runtime: 634.200  Train loss: 2.791.. Validation loss: 2.399.. Validation accuracy: 0.559
# Epoch 2/20 Step 200 Runtime: 668.059  Train loss: 2.884.. Validation loss: 2.286.. Validation accuracy: 0.586
# Epoch 3/20 Step 210 Runtime: 701.421  Train loss: 2.752.. Validation loss: 2.196.. Validation accuracy: 0.610
# Epoch 3/20 Step 220 Runtime: 735.601  Train loss: 2.555.. Validation loss: 2.113.. Validation accuracy: 0.633
# Epoch 3/20 Step 230 Runtime: 769.337  Train loss: 2.694.. Validation loss: 2.049.. Validation accuracy: 0.646
# Epoch 3/20 Step 240 Runtime: 802.993  Train loss: 2.482.. Validation loss: 1.981.. Validation accuracy: 0.655
# Epoch 3/20 Step 250 Runtime: 836.679  Train loss: 2.390.. Validation loss: 1.932.. Validation accuracy: 0.656
# Epoch 3/20 Step 260 Runtime: 870.370  Train loss: 2.453.. Validation loss: 1.875.. Validation accuracy: 0.681
# Epoch 3/20 Step 270 Runtime: 904.037  Train loss: 2.370.. Validation loss: 1.780.. Validation accuracy: 0.691
# Epoch 3/20 Step 280 Runtime: 937.937  Train loss: 2.258.. Validation loss: 1.740.. Validation accuracy: 0.693
# Epoch 3/20 Step 290 Runtime: 972.292  Train loss: 2.201.. Validation loss: 1.691.. Validation accuracy: 0.690
# Epoch 3/20 Step 300 Runtime: 1006.008  Train loss: 2.229.. Validation loss: 1.644.. Validation accuracy: 0.707
# Epoch 4/20 Step 310 Runtime: 1039.002  Train loss: 2.105.. Validation loss: 1.579.. Validation accuracy: 0.733
# Epoch 4/20 Step 320 Runtime: 1072.801  Train loss: 2.084.. Validation loss: 1.539.. Validation accuracy: 0.730
# Epoch 4/20 Step 330 Runtime: 1106.646  Train loss: 2.102.. Validation loss: 1.497.. Validation accuracy: 0.739
# Epoch 4/20 Step 340 Runtime: 1140.533  Train loss: 1.990.. Validation loss: 1.449.. Validation accuracy: 0.751
# Epoch 4/20 Step 350 Runtime: 1174.367  Train loss: 1.875.. Validation loss: 1.402.. Validation accuracy: 0.761
# Epoch 4/20 Step 360 Runtime: 1208.453  Train loss: 1.885.. Validation loss: 1.359.. Validation accuracy: 0.767
# Epoch 4/20 Step 370 Runtime: 1242.512  Train loss: 1.860.. Validation loss: 1.331.. Validation accuracy: 0.764
# Epoch 4/20 Step 380 Runtime: 1276.248  Train loss: 1.880.. Validation loss: 1.316.. Validation accuracy: 0.768
# Epoch 4/20 Step 390 Runtime: 1310.117  Train loss: 1.820.. Validation loss: 1.256.. Validation accuracy: 0.787
# Epoch 4/20 Step 400 Runtime: 1344.009  Train loss: 1.852.. Validation loss: 1.217.. Validation accuracy: 0.802
# Epoch 4/20 Step 410 Runtime: 1377.424  Train loss: 1.763.. Validation loss: 1.195.. Validation accuracy: 0.812
# Epoch 5/20 Step 420 Runtime: 1410.287  Train loss: 1.678.. Validation loss: 1.171.. Validation accuracy: 0.802
# Epoch 5/20 Step 430 Runtime: 1444.133  Train loss: 1.650.. Validation loss: 1.132.. Validation accuracy: 0.794
# Epoch 5/20 Step 440 Runtime: 1477.680  Train loss: 1.654.. Validation loss: 1.095.. Validation accuracy: 0.820
# Epoch 5/20 Step 450 Runtime: 1511.241  Train loss: 1.682.. Validation loss: 1.083.. Validation accuracy: 0.821
# Epoch 5/20 Step 460 Runtime: 1545.255  Train loss: 1.559.. Validation loss: 1.071.. Validation accuracy: 0.826
# Epoch 5/20 Step 470 Runtime: 1579.206  Train loss: 1.579.. Validation loss: 1.056.. Validation accuracy: 0.825
# Epoch 5/20 Step 480 Runtime: 1613.135  Train loss: 1.522.. Validation loss: 1.013.. Validation accuracy: 0.820
# Epoch 5/20 Step 490 Runtime: 1647.247  Train loss: 1.515.. Validation loss: 0.979.. Validation accuracy: 0.827
# Epoch 5/20 Step 500 Runtime: 1681.561  Train loss: 1.603.. Validation loss: 0.956.. Validation accuracy: 0.844
# Epoch 5/20 Step 510 Runtime: 1715.463  Train loss: 1.498.. Validation loss: 0.940.. Validation accuracy: 0.838
# Epoch 6/20 Step 520 Runtime: 1748.511  Train loss: 1.467.. Validation loss: 0.924.. Validation accuracy: 0.846
# Epoch 6/20 Step 530 Runtime: 1782.626  Train loss: 1.500.. Validation loss: 0.903.. Validation accuracy: 0.861
# Epoch 6/20 Step 540 Runtime: 1816.874  Train loss: 1.388.. Validation loss: 0.887.. Validation accuracy: 0.853
# Epoch 6/20 Step 550 Runtime: 1850.874  Train loss: 1.436.. Validation loss: 0.878.. Validation accuracy: 0.855
# Epoch 6/20 Step 560 Runtime: 1885.087  Train loss: 1.337.. Validation loss: 0.855.. Validation accuracy: 0.858
# Epoch 6/20 Step 570 Runtime: 1919.602  Train loss: 1.315.. Validation loss: 0.831.. Validation accuracy: 0.863
# Epoch 6/20 Step 580 Runtime: 1953.995  Train loss: 1.341.. Validation loss: 0.819.. Validation accuracy: 0.860
# Epoch 6/20 Step 590 Runtime: 1988.119  Train loss: 1.325.. Validation loss: 0.804.. Validation accuracy: 0.852
# Epoch 6/20 Step 600 Runtime: 2021.996  Train loss: 1.232.. Validation loss: 0.782.. Validation accuracy: 0.853
# Epoch 6/20 Step 610 Runtime: 2055.911  Train loss: 1.372.. Validation loss: 0.774.. Validation accuracy: 0.853
# Epoch 7/20 Step 620 Runtime: 2088.938  Train loss: 1.356.. Validation loss: 0.765.. Validation accuracy: 0.874
# Epoch 7/20 Step 630 Runtime: 2122.644  Train loss: 1.304.. Validation loss: 0.754.. Validation accuracy: 0.885
# Epoch 7/20 Step 640 Runtime: 2156.451  Train loss: 1.279.. Validation loss: 0.744.. Validation accuracy: 0.882
# Epoch 7/20 Step 650 Runtime: 2190.640  Train loss: 1.265.. Validation loss: 0.737.. Validation accuracy: 0.874
# Epoch 7/20 Step 660 Runtime: 2224.439  Train loss: 1.207.. Validation loss: 0.707.. Validation accuracy: 0.877
# Epoch 7/20 Step 670 Runtime: 2258.434  Train loss: 1.133.. Validation loss: 0.699.. Validation accuracy: 0.885
# Epoch 7/20 Step 680 Runtime: 2292.273  Train loss: 1.099.. Validation loss: 0.680.. Validation accuracy: 0.889
# Epoch 7/20 Step 690 Runtime: 2326.070  Train loss: 1.264.. Validation loss: 0.681.. Validation accuracy: 0.875
# Epoch 7/20 Step 700 Runtime: 2359.948  Train loss: 1.135.. Validation loss: 0.660.. Validation accuracy: 0.874
# Epoch 7/20 Step 710 Runtime: 2394.068  Train loss: 1.195.. Validation loss: 0.668.. Validation accuracy: 0.883
# Epoch 7/20 Step 720 Runtime: 2429.012  Train loss: 1.075.. Validation loss: 0.649.. Validation accuracy: 0.889
# Epoch 8/20 Step 730 Runtime: 2462.229  Train loss: 1.152.. Validation loss: 0.643.. Validation accuracy: 0.886
# Epoch 8/20 Step 740 Runtime: 2495.982  Train loss: 1.174.. Validation loss: 0.636.. Validation accuracy: 0.893
# Epoch 8/20 Step 750 Runtime: 2529.944  Train loss: 1.100.. Validation loss: 0.623.. Validation accuracy: 0.884
# Epoch 8/20 Step 760 Runtime: 2563.944  Train loss: 1.110.. Validation loss: 0.612.. Validation accuracy: 0.899
# Epoch 8/20 Step 770 Runtime: 2597.718  Train loss: 1.037.. Validation loss: 0.604.. Validation accuracy: 0.901
# Epoch 8/20 Step 780 Runtime: 2631.689  Train loss: 1.054.. Validation loss: 0.588.. Validation accuracy: 0.893
# Epoch 8/20 Step 790 Runtime: 2665.767  Train loss: 1.069.. Validation loss: 0.587.. Validation accuracy: 0.883
# Epoch 8/20 Step 800 Runtime: 2699.633  Train loss: 1.031.. Validation loss: 0.585.. Validation accuracy: 0.892
# Epoch 8/20 Step 810 Runtime: 2733.300  Train loss: 1.000.. Validation loss: 0.591.. Validation accuracy: 0.892
# Epoch 8/20 Step 820 Runtime: 2766.926  Train loss: 1.023.. Validation loss: 0.573.. Validation accuracy: 0.901
# Epoch 9/20 Step 830 Runtime: 2799.845  Train loss: 0.975.. Validation loss: 0.560.. Validation accuracy: 0.900
# Epoch 9/20 Step 840 Runtime: 2833.477  Train loss: 0.996.. Validation loss: 0.554.. Validation accuracy: 0.909
# Epoch 9/20 Step 850 Runtime: 2867.375  Train loss: 1.036.. Validation loss: 0.553.. Validation accuracy: 0.901
# Epoch 9/20 Step 860 Runtime: 2901.543  Train loss: 0.950.. Validation loss: 0.542.. Validation accuracy: 0.901
# Epoch 9/20 Step 870 Runtime: 2935.423  Train loss: 1.080.. Validation loss: 0.542.. Validation accuracy: 0.896
# Epoch 9/20 Step 880 Runtime: 2969.057  Train loss: 0.938.. Validation loss: 0.522.. Validation accuracy: 0.899
# Epoch 9/20 Step 890 Runtime: 3002.617  Train loss: 0.997.. Validation loss: 0.513.. Validation accuracy: 0.911
# Epoch 9/20 Step 900 Runtime: 3036.079  Train loss: 0.885.. Validation loss: 0.508.. Validation accuracy: 0.905
# Epoch 9/20 Step 910 Runtime: 3069.716  Train loss: 0.948.. Validation loss: 0.506.. Validation accuracy: 0.908
# Epoch 9/20 Step 920 Runtime: 3103.342  Train loss: 0.950.. Validation loss: 0.503.. Validation accuracy: 0.911
# Epoch 10/20 Step 930 Runtime: 3136.429  Train loss: 0.918.. Validation loss: 0.486.. Validation accuracy: 0.917
# Epoch 10/20 Step 940 Runtime: 3169.948  Train loss: 0.924.. Validation loss: 0.481.. Validation accuracy: 0.911
# Epoch 10/20 Step 950 Runtime: 3203.210  Train loss: 0.871.. Validation loss: 0.489.. Validation accuracy: 0.914
# Epoch 10/20 Step 960 Runtime: 3236.587  Train loss: 0.900.. Validation loss: 0.483.. Validation accuracy: 0.916
# Epoch 10/20 Step 970 Runtime: 3270.108  Train loss: 0.901.. Validation loss: 0.479.. Validation accuracy: 0.917
# Epoch 10/20 Step 980 Runtime: 3303.496  Train loss: 0.852.. Validation loss: 0.482.. Validation accuracy: 0.908
# Epoch 10/20 Step 990 Runtime: 3336.979  Train loss: 0.897.. Validation loss: 0.461.. Validation accuracy: 0.913
# Epoch 10/20 Step 1000 Runtime: 3370.532  Train loss: 0.897.. Validation loss: 0.460.. Validation accuracy: 0.909
# Epoch 10/20 Step 1010 Runtime: 3404.110  Train loss: 0.968.. Validation loss: 0.465.. Validation accuracy: 0.912
# Epoch 10/20 Step 1020 Runtime: 3437.585  Train loss: 0.839.. Validation loss: 0.457.. Validation accuracy: 0.915
# Epoch 10/20 Step 1030 Runtime: 3470.259  Train loss: 0.780.. Validation loss: 0.451.. Validation accuracy: 0.909
# Epoch 11/20 Step 1040 Runtime: 3503.590  Train loss: 0.861.. Validation loss: 0.461.. Validation accuracy: 0.915
# Epoch 11/20 Step 1050 Runtime: 3537.028  Train loss: 0.831.. Validation loss: 0.454.. Validation accuracy: 0.915
# Epoch 11/20 Step 1060 Runtime: 3570.381  Train loss: 0.777.. Validation loss: 0.445.. Validation accuracy: 0.918
# Epoch 11/20 Step 1070 Runtime: 3604.040  Train loss: 0.831.. Validation loss: 0.438.. Validation accuracy: 0.925
# Epoch 11/20 Step 1080 Runtime: 3637.321  Train loss: 0.786.. Validation loss: 0.432.. Validation accuracy: 0.918
# Epoch 11/20 Step 1090 Runtime: 3670.599  Train loss: 0.818.. Validation loss: 0.425.. Validation accuracy: 0.914
# Epoch 11/20 Step 1100 Runtime: 3703.969  Train loss: 0.874.. Validation loss: 0.418.. Validation accuracy: 0.914
# Epoch 11/20 Step 1110 Runtime: 3737.571  Train loss: 0.791.. Validation loss: 0.423.. Validation accuracy: 0.916
# Epoch 11/20 Step 1120 Runtime: 3771.414  Train loss: 0.826.. Validation loss: 0.425.. Validation accuracy: 0.916
# Epoch 11/20 Step 1130 Runtime: 3805.087  Train loss: 0.798.. Validation loss: 0.412.. Validation accuracy: 0.918
# Epoch 12/20 Step 1140 Runtime: 3837.852  Train loss: 0.749.. Validation loss: 0.416.. Validation accuracy: 0.916
# Epoch 12/20 Step 1150 Runtime: 3871.813  Train loss: 0.863.. Validation loss: 0.406.. Validation accuracy: 0.919
# Epoch 12/20 Step 1160 Runtime: 3905.233  Train loss: 0.817.. Validation loss: 0.407.. Validation accuracy: 0.927
# Epoch 12/20 Step 1170 Runtime: 3938.650  Train loss: 0.747.. Validation loss: 0.401.. Validation accuracy: 0.924
# Epoch 12/20 Step 1180 Runtime: 3972.089  Train loss: 0.761.. Validation loss: 0.396.. Validation accuracy: 0.923
# Epoch 12/20 Step 1190 Runtime: 4005.490  Train loss: 0.718.. Validation loss: 0.392.. Validation accuracy: 0.921
# Epoch 12/20 Step 1200 Runtime: 4038.905  Train loss: 0.687.. Validation loss: 0.388.. Validation accuracy: 0.919
# Epoch 12/20 Step 1210 Runtime: 4072.336  Train loss: 0.737.. Validation loss: 0.389.. Validation accuracy: 0.931
# Epoch 12/20 Step 1220 Runtime: 4106.111  Train loss: 0.760.. Validation loss: 0.383.. Validation accuracy: 0.931
# Epoch 12/20 Step 1230 Runtime: 4139.556  Train loss: 0.695.. Validation loss: 0.385.. Validation accuracy: 0.933
# Epoch 13/20 Step 1240 Runtime: 4172.339  Train loss: 0.718.. Validation loss: 0.382.. Validation accuracy: 0.929
# Epoch 13/20 Step 1250 Runtime: 4205.655  Train loss: 0.757.. Validation loss: 0.382.. Validation accuracy: 0.927
# Epoch 13/20 Step 1260 Runtime: 4238.958  Train loss: 0.730.. Validation loss: 0.375.. Validation accuracy: 0.920
# Epoch 13/20 Step 1270 Runtime: 4272.467  Train loss: 0.747.. Validation loss: 0.366.. Validation accuracy: 0.932
# Epoch 13/20 Step 1280 Runtime: 4305.878  Train loss: 0.740.. Validation loss: 0.361.. Validation accuracy: 0.936
# Epoch 13/20 Step 1290 Runtime: 4339.703  Train loss: 0.777.. Validation loss: 0.367.. Validation accuracy: 0.938
# Epoch 13/20 Step 1300 Runtime: 4373.360  Train loss: 0.706.. Validation loss: 0.367.. Validation accuracy: 0.935
# Epoch 13/20 Step 1310 Runtime: 4406.858  Train loss: 0.737.. Validation loss: 0.360.. Validation accuracy: 0.937
# Epoch 13/20 Step 1320 Runtime: 4440.338  Train loss: 0.800.. Validation loss: 0.363.. Validation accuracy: 0.933
# Epoch 13/20 Step 1330 Runtime: 4473.556  Train loss: 0.706.. Validation loss: 0.357.. Validation accuracy: 0.928
# Epoch 14/20 Step 1340 Runtime: 4506.243  Train loss: 0.773.. Validation loss: 0.363.. Validation accuracy: 0.922
# Epoch 14/20 Step 1350 Runtime: 4539.610  Train loss: 0.773.. Validation loss: 0.359.. Validation accuracy: 0.923
# Epoch 14/20 Step 1360 Runtime: 4573.351  Train loss: 0.690.. Validation loss: 0.353.. Validation accuracy: 0.929
# Epoch 14/20 Step 1370 Runtime: 4606.818  Train loss: 0.692.. Validation loss: 0.349.. Validation accuracy: 0.924
# Epoch 14/20 Step 1380 Runtime: 4640.308  Train loss: 0.629.. Validation loss: 0.346.. Validation accuracy: 0.930
# Epoch 14/20 Step 1390 Runtime: 4673.762  Train loss: 0.711.. Validation loss: 0.347.. Validation accuracy: 0.925
# Epoch 14/20 Step 1400 Runtime: 4707.241  Train loss: 0.724.. Validation loss: 0.339.. Validation accuracy: 0.931
# Epoch 14/20 Step 1410 Runtime: 4740.799  Train loss: 0.697.. Validation loss: 0.340.. Validation accuracy: 0.928
# Epoch 14/20 Step 1420 Runtime: 4774.426  Train loss: 0.666.. Validation loss: 0.336.. Validation accuracy: 0.934
# Epoch 14/20 Step 1430 Runtime: 4808.388  Train loss: 0.670.. Validation loss: 0.340.. Validation accuracy: 0.934
# Epoch 14/20 Step 1440 Runtime: 4841.828  Train loss: 0.760.. Validation loss: 0.333.. Validation accuracy: 0.935
# Epoch 15/20 Step 1450 Runtime: 4874.860  Train loss: 0.634.. Validation loss: 0.326.. Validation accuracy: 0.939
# Epoch 15/20 Step 1460 Runtime: 4908.438  Train loss: 0.626.. Validation loss: 0.328.. Validation accuracy: 0.940
# Epoch 15/20 Step 1470 Runtime: 4941.999  Train loss: 0.657.. Validation loss: 0.331.. Validation accuracy: 0.941
# Epoch 15/20 Step 1480 Runtime: 4975.626  Train loss: 0.672.. Validation loss: 0.324.. Validation accuracy: 0.941
# Epoch 15/20 Step 1490 Runtime: 5009.231  Train loss: 0.676.. Validation loss: 0.324.. Validation accuracy: 0.937
# Epoch 15/20 Step 1500 Runtime: 5043.178  Train loss: 0.660.. Validation loss: 0.327.. Validation accuracy: 0.934
# Epoch 15/20 Step 1510 Runtime: 5076.758  Train loss: 0.692.. Validation loss: 0.325.. Validation accuracy: 0.938
# Epoch 15/20 Step 1520 Runtime: 5110.268  Train loss: 0.653.. Validation loss: 0.321.. Validation accuracy: 0.934
# Epoch 15/20 Step 1530 Runtime: 5143.697  Train loss: 0.677.. Validation loss: 0.326.. Validation accuracy: 0.940
# Epoch 15/20 Step 1540 Runtime: 5177.149  Train loss: 0.596.. Validation loss: 0.322.. Validation accuracy: 0.938
# Epoch 16/20 Step 1550 Runtime: 5210.136  Train loss: 0.622.. Validation loss: 0.315.. Validation accuracy: 0.939
# Epoch 16/20 Step 1560 Runtime: 5243.625  Train loss: 0.668.. Validation loss: 0.317.. Validation accuracy: 0.935
# Epoch 16/20 Step 1570 Runtime: 5277.070  Train loss: 0.616.. Validation loss: 0.314.. Validation accuracy: 0.935
# Epoch 16/20 Step 1580 Runtime: 5310.953  Train loss: 0.584.. Validation loss: 0.313.. Validation accuracy: 0.940
# Epoch 16/20 Step 1590 Runtime: 5344.614  Train loss: 0.638.. Validation loss: 0.305.. Validation accuracy: 0.941
# Epoch 16/20 Step 1600 Runtime: 5378.120  Train loss: 0.588.. Validation loss: 0.309.. Validation accuracy: 0.940
# Epoch 16/20 Step 1610 Runtime: 5411.638  Train loss: 0.634.. Validation loss: 0.316.. Validation accuracy: 0.938
# Epoch 16/20 Step 1620 Runtime: 5445.227  Train loss: 0.638.. Validation loss: 0.320.. Validation accuracy: 0.935
# Epoch 16/20 Step 1630 Runtime: 5478.893  Train loss: 0.661.. Validation loss: 0.312.. Validation accuracy: 0.941
# Epoch 16/20 Step 1640 Runtime: 5512.695  Train loss: 0.673.. Validation loss: 0.299.. Validation accuracy: 0.940
# Epoch 17/20 Step 1650 Runtime: 5545.928  Train loss: 0.622.. Validation loss: 0.299.. Validation accuracy: 0.939
# Epoch 17/20 Step 1660 Runtime: 5579.389  Train loss: 0.626.. Validation loss: 0.304.. Validation accuracy: 0.940
# Epoch 17/20 Step 1670 Runtime: 5613.188  Train loss: 0.593.. Validation loss: 0.301.. Validation accuracy: 0.944
# Epoch 17/20 Step 1680 Runtime: 5646.554  Train loss: 0.666.. Validation loss: 0.302.. Validation accuracy: 0.939
# Epoch 17/20 Step 1690 Runtime: 5679.884  Train loss: 0.659.. Validation loss: 0.298.. Validation accuracy: 0.941
# Epoch 17/20 Step 1700 Runtime: 5713.429  Train loss: 0.557.. Validation loss: 0.291.. Validation accuracy: 0.937
# Epoch 17/20 Step 1710 Runtime: 5746.931  Train loss: 0.589.. Validation loss: 0.290.. Validation accuracy: 0.936
# Epoch 17/20 Step 1720 Runtime: 5780.540  Train loss: 0.608.. Validation loss: 0.292.. Validation accuracy: 0.944
# Epoch 17/20 Step 1730 Runtime: 5813.866  Train loss: 0.632.. Validation loss: 0.292.. Validation accuracy: 0.941
# Epoch 17/20 Step 1740 Runtime: 5847.298  Train loss: 0.538.. Validation loss: 0.286.. Validation accuracy: 0.940
# Epoch 17/20 Step 1750 Runtime: 5880.835  Train loss: 0.569.. Validation loss: 0.286.. Validation accuracy: 0.940
# Epoch 18/20 Step 1760 Runtime: 5913.473  Train loss: 0.615.. Validation loss: 0.298.. Validation accuracy: 0.935
# Epoch 18/20 Step 1770 Runtime: 5946.928  Train loss: 0.597.. Validation loss: 0.305.. Validation accuracy: 0.939
# Epoch 18/20 Step 1780 Runtime: 5980.355  Train loss: 0.612.. Validation loss: 0.295.. Validation accuracy: 0.939
# Epoch 18/20 Step 1790 Runtime: 6014.056  Train loss: 0.598.. Validation loss: 0.290.. Validation accuracy: 0.939
# Epoch 18/20 Step 1800 Runtime: 6047.489  Train loss: 0.521.. Validation loss: 0.277.. Validation accuracy: 0.944
# Epoch 18/20 Step 1810 Runtime: 6081.070  Train loss: 0.506.. Validation loss: 0.277.. Validation accuracy: 0.949
# Epoch 18/20 Step 1820 Runtime: 6114.541  Train loss: 0.506.. Validation loss: 0.283.. Validation accuracy: 0.946
# Epoch 18/20 Step 1830 Runtime: 6147.953  Train loss: 0.563.. Validation loss: 0.283.. Validation accuracy: 0.947
# Epoch 18/20 Step 1840 Runtime: 6181.393  Train loss: 0.567.. Validation loss: 0.282.. Validation accuracy: 0.942
# Epoch 18/20 Step 1850 Runtime: 6214.802  Train loss: 0.604.. Validation loss: 0.288.. Validation accuracy: 0.944
# Epoch 19/20 Step 1860 Runtime: 6248.191  Train loss: 0.570.. Validation loss: 0.284.. Validation accuracy: 0.939
# Epoch 19/20 Step 1870 Runtime: 6281.721  Train loss: 0.607.. Validation loss: 0.276.. Validation accuracy: 0.937
# Epoch 19/20 Step 1880 Runtime: 6315.218  Train loss: 0.567.. Validation loss: 0.276.. Validation accuracy: 0.943
# Epoch 19/20 Step 1890 Runtime: 6348.672  Train loss: 0.587.. Validation loss: 0.275.. Validation accuracy: 0.944
# Epoch 19/20 Step 1900 Runtime: 6382.032  Train loss: 0.475.. Validation loss: 0.274.. Validation accuracy: 0.943
# Epoch 19/20 Step 1910 Runtime: 6415.399  Train loss: 0.579.. Validation loss: 0.266.. Validation accuracy: 0.946
# Epoch 19/20 Step 1920 Runtime: 6448.803  Train loss: 0.587.. Validation loss: 0.262.. Validation accuracy: 0.950
# Epoch 19/20 Step 1930 Runtime: 6482.702  Train loss: 0.604.. Validation loss: 0.269.. Validation accuracy: 0.951
# Epoch 19/20 Step 1940 Runtime: 6516.193  Train loss: 0.552.. Validation loss: 0.275.. Validation accuracy: 0.949
# Epoch 19/20 Step 1950 Runtime: 6549.648  Train loss: 0.502.. Validation loss: 0.273.. Validation accuracy: 0.950
# Epoch 20/20 Step 1960 Runtime: 6582.439  Train loss: 0.533.. Validation loss: 0.274.. Validation accuracy: 0.945
# Epoch 20/20 Step 1970 Runtime: 6615.923  Train loss: 0.581.. Validation loss: 0.276.. Validation accuracy: 0.942
# Epoch 20/20 Step 1980 Runtime: 6649.303  Train loss: 0.571.. Validation loss: 0.281.. Validation accuracy: 0.939
# Epoch 20/20 Step 1990 Runtime: 6682.798  Train loss: 0.488.. Validation loss: 0.280.. Validation accuracy: 0.940
# Epoch 20/20 Step 2000 Runtime: 6716.224  Train loss: 0.599.. Validation loss: 0.273.. Validation accuracy: 0.945
# Epoch 20/20 Step 2010 Runtime: 6749.866  Train loss: 0.622.. Validation loss: 0.265.. Validation accuracy: 0.944
# Epoch 20/20 Step 2020 Runtime: 6783.325  Train loss: 0.570.. Validation loss: 0.258.. Validation accuracy: 0.945
# Epoch 20/20 Step 2030 Runtime: 6816.769  Train loss: 0.556.. Validation loss: 0.260.. Validation accuracy: 0.947
# Epoch 20/20 Step 2040 Runtime: 6850.344  Train loss: 0.524.. Validation loss: 0.259.. Validation accuracy: 0.950
# Epoch 20/20 Step 2050 Runtime: 6883.767  Train loss: 0.523.. Validation loss: 0.256.. Validation accuracy: 0.951
# Epoch 20/20 Step 2060 Runtime: 6916.515  Train loss: 0.523.. Validation loss: 0.257.. Validation accuracy: 0.950

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set
def test_model(model, testloader):
    test_loss = 0
    accuracy = 0
    criterion = nn.NLLLoss()

    model.eval()
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            logps = model.forward(inputs)
            batch_loss = criterion(logps, labels)

            test_loss += batch_loss.item()

            # Calculate accuracy
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

    print(#f"Epoch {epoch+1}/{epochs}.. "
          f"Test loss: {test_loss/len(testloader):.3f}.. "
          f"Test accuracy: {accuracy/len(testloader):.3f}")

# %%
test_model(my_model, testloader)
# Out:
# Test loss: 0.281.. Test accuracy: 0.940

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Save the checkpoint 
my_model.class_to_idx = train_data.class_to_idx
checkpoint = {'class_to_idx': train_data.class_to_idx,
              'state_dict': my_model.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath, model):
    checkpoint = torch.load(filepath)
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx = checkpoint['class_to_idx']

    return model

# %%
# Define a model with the same architecture
vgg = models.vgg19_bn()
my_vgg = redefin_model(vgg)

# %%
# Load the saved model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_loaded = load_checkpoint('checkpoint.pth', my_vgg)
print(model_loaded)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu): ReLU()
#     (dropout1): Dropout(p=0.2)
#     (fc2): Linear(in_features=1024, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# Test the reloaded model
# model_loaded.cuda()
model_loaded.to(device);
test_model(model_loaded, testloader)
# Out:
# Test loss: 0.281.. Test accuracy: 0.940

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    im = Image.open(image)
    im = im.resize((256, 256))
    im = im.crop((16,16, 240, 240))
    np_image = np.asarray(im)
    np_image = np_image / 255
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])

    np_image = (np_image - mean) / std
    np_image = np_image.transpose((2, 0, 1))
    return torch.from_numpy(np_image).type(torch.FloatTensor)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    ax.set_title(title)

    ax.imshow(image)
    
    return ax

# %%
image_path = test_dir+'/78/image_01949.jpg'
imshow(process_image(image_path))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
# Make a map for label index to class
# model_loaded.class_to_idx
idx_to_class  = {v: k for k, v in model_loaded.class_to_idx.items()}

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # Implement the code to predict the class from an image file
    model.eval()
    img = process_image(image_path)
    # Align the dimension of input image
    imgs = img[None, :]
    imgs = imgs.to(device)

    with torch.no_grad():
        output = model.forward(imgs)

    ps = torch.exp(output)

    top_p, top_idx = ps.topk(topk, dim=1)

    # Squeeze the tensor, then conver to numpy array
    top_p = torch.squeeze(top_p).cpu().numpy()
    top_idx = torch.squeeze(top_idx).cpu().numpy()
    top_class = [idx_to_class[x] for x in top_idx] 
    # Look at the most likely classes for the topk examples
    return top_p, top_class

# %%
imgs = ['/1/image_06752.jpg', '/22/image_05362.jpg', '/78/image_01949.jpg']

for img in imgs:  
  probs, classes = predict(test_dir+img, model_loaded)
  print(probs)
  print(classes)
# Out:
# [ 0.31511876  0.19427741  0.08148684  0.04626725  0.02048597]
# ['67', '1', '19', '65', '57']
# [  9.82258737e-01   1.07422899e-02   3.12163541e-03   1.86041917e-03
#    4.06953797e-04]
# ['22', '38', '92', '31', '40']
# [ 0.95691413  0.01538616  0.0122218   0.00705701  0.00143517]
# ['78', '39', '88', '73', '69']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def view_classify_result(img_path, probs, classes):
    ''' Function for viewing an image and it's predicted classes.
    '''
    
    img_label_class = img_path.split('/')[2]

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    imshow(process_image(img_path), ax=ax1, title=cat_to_name[img_label_class])

#     ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    
    ax2.barh(np.arange(5), probs)
    ax2.set_aspect(0.2)
    ax2.set_yticks(np.arange(5))
    
    ax2.set_yticklabels([cat_to_name[idx] for idx in classes], size='small');
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

# %%
# randomly choose 10 class of pictures to test
import random
import os

cat_list = [i for i in range(1, 103)]
random.shuffle(cat_list)
cat_select = cat_list[:10]

test_files = []
for cat in cat_select:
  for root, dirs, files in os.walk('{}/{}'.format(test_dir, cat)):
    random.shuffle(files)
    test_files.append('/{}/{}'.format(cat,files[0]))
    break

# %%
# imgs = ['/15/image_06369.jpg', '/12/image_03996.jpg', '/22/image_05362.jpg', 
#         '/78/image_01949.jpg', '/99/image_07833.jpg', '/100/image_07902.jpg']

for img in test_files:
    img = test_dir + img
    probs, classes = predict(img, model_loaded)
    view_classify_result(img, probs, classes)
